# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("aac_intakes_outcomes.csv")

# %%
total_by_breedType = data.groupby("breed").count()["animal_type"]
total_by_breedType = total_by_breedType.reset_index()
total_by_breedType = total_by_breedType.rename(columns =  {"breed":"Breed", "animal_type":"Totals"})
total_by_breedType
# Out:
#                                               Breed  Totals
# 0                                    Abyssinian Mix       4
# 1                                 Affenpinscher Mix       7
# 2                                  Afghan Hound Mix       1
# 3                   Afghan Hound/Labrador Retriever       1
# 4                                       African Mix       1
# 5                                  Airedale Terrier       1
# 6                              Airedale Terrier Mix      15
# 7                    Airedale Terrier/Irish Terrier       1
# 8               Airedale Terrier/Labrador Retriever       2
# 9              Airedale Terrier/Miniature Schnauzer       1
# 10                      Airedale Terrier/Otterhound       1
# 11                                       Akbash Mix       5
# 12                                            Akita       7
# 13                                        Akita Mix      40
# 14                      Akita/Australian Cattle Dog       3
# ...
